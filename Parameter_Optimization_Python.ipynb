# %% [markdown]
# # <font color='blue'>Parameter Optimization with Randomized Search</font>

# %% [markdown]
# Every machine learning model has parameters that allow the customization of the model. These parameters are also called hyperparameters.
#
# Functions in programming represent machine learning algorithms, and each function has the customization parameters, precisely what we call hyperparameters.
#
# It is also common for people to report to the model's coefficients (found at the end of training) as parameters.
#
# Part of our job as Data Scientists is to find the best combination of hyperparameters for each model.
#
# In Ensemble Methods, we have the hyperparameters of the base estimator and the hyperparameters of the ensemble model:
#
# * Base estimator:
#
# estim_base = KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski', metric_params=None, n_jobs=None, n_neighbors=5, p=2, weights='uniform')
#
# * Ensemble Model:
#
# BaggingClassifier(base_estimator=estim_base,
#                   bootstrap=True, bootstrap_features=False, max_features=0.5,
#                   max_samples=0.5, n_estimators=10, n_jobs=None,
#                   oob_score=False, random_state=None, verbose=0,
#                   warm_start=False)

# %% [markdown]
# ## Extremely Randomized Forest

# %% [markdown]
# Standard model, with manually chosen hyperparameters.

# %%
# Importing libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Loading dataset
data = pd.read_excel('data/credit.xls', skiprows = 1)

# %%
print(data)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -1  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 25 columns]

# %%
# setting target
target = 'default payment next month'
y = np.asarray(data[target])

# %%
# setting predictors
features = data.columns.drop(['ID', target])
X = np.asarray(data[features])

# %%
# Splitting of training and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 99)

# %%
# Creating classifier
clf = ExtraTreesClassifier(n_estimators = 500, random_state = 99)

# %%
# Training model
clf.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#                      max_depth=None, max_features='auto', max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=500,
#                      n_jobs=None, oob_score=False, random_state=99, verbose=0,
#                      warm_start=False)

# %%
# Score
scores = cross_val_score(clf, X_train, y_train, cv = 3, scoring = 'accuracy', n_jobs = -1)

# %%
# Printing
print ("ExtraTreesClassifier -> Training Accuracy: Average = %0.3f Standard Deviation = %0.3f" % (np.mean(scores), np.std(scores)))
# Out:
# ExtraTreesClassifier -> Acurácia em Treino: Média = 0.812 Desvio Padrão = 0.002

# %%
# Predictions
y_pred = clf.predict(X_test)

# %%
# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print (confusionMatrix)
# Out:
# [[6532  446]
#  [1273  749]]

# %%
# Accuracy
print("Acurácia em Teste:", accuracy_score(y_test, y_pred))
# Out:
# Acurácia em Teste: 0.809

# %% [markdown]
# ## Hyperparameter Optimization with Randomized Search

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# Randomized Search generates samples of algorithm parameters from a uniform random distribution to a fixed number of interactions. A model is built and tested for each combination of parameters.

# %%
# Import
from sklearn.model_selection import RandomizedSearchCV

# %%
# Setting of parameters
param_dist = {"max_depth": [1, 3, 7, 8, 12, None],
              "max_features": [8, 9, 10, 11, 16, 22],
              "min_samples_split": [8, 10, 11, 14, 16, 19],
              "min_samples_leaf": [1, 2, 3, 4, 5, 6, 7],
              "bootstrap": [True, False]}

# For the classifier created with ExtraTrees, we tested different combinations of parameters
rsearch = RandomizedSearchCV(clf, param_distributions = param_dist, n_iter = 25, return_train_score = True)  

# Applying the result to the training data set and getting the score
rsearch.fit(X_train, y_train)

# Results 
rsearch.cv_results_

# Printing the best estimator
bestclf = rsearch.best_estimator_
print (bestclf)

# Applying the best estimator to carry out the predictions
y_pred = bestclf.predict(X_test)

# Confusion Matrix
confusionMatrix = confusion_matrix(y_test, y_pred)
print(confusionMatrix)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# ExtraTreesClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                      max_depth=7, max_features=22, max_leaf_nodes=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=6, min_samples_split=11,
#                      min_weight_fraction_leaf=0.0, n_estimators=500,
#                      n_jobs=None, oob_score=False, random_state=99, verbose=0,
#                      warm_start=False)
# [[6652  326]
#  [1290  732]]
# 0.8204444444444444

# %%
# Getting the grid with all parameter combinations
rsearch.cv_results_
# Out:
# {'mean_fit_time': array([ 1.73276591,  5.6754566 ,  1.44881407,  4.86209957,  1.86060635,
#          3.19942625,  2.48792402,  1.19794106,  1.12878776,  5.68522199,
#          7.05678161,  1.71638417,  4.21872195,  1.65388274,  2.76597857,
#          7.6410505 ,  3.42891932,  4.48763871,  8.6336147 ,  1.6180977 ,
#         17.13844609,  1.2311066 ,  1.72368709,  1.74332809,  5.33069785]),
#  'std_fit_time': array([0.02920974, 0.13275819, 0.02895639, 0.12291092, 0.01744542,
#         0.11123478, 0.03371552, 0.05790591, 0.05005262, 0.09638464,
#         0.11958016, 0.00921741, 0.01845165, 0.0097986 , 0.01785686,
#         0.05675859, 0.05520176, 0.0278813 , 0.11361021, 0.01553819,
#         0.48353004, 0.03080309, 0.06647351, 0.10591987, 0.20548049]),
#  'mean_score_time': array([0.18082841, 0.50313139, 0.13964534, 0.26077239, 0.17606695,
#         0.22832497, 0.23130226, 0.15233994, 0.1467642 , 0.35081633,
#         0.57697352, 0.16485286, 0.23387305, 0.16475828, 0.16421469,
#         0.50292643, 0.33973002, 0.47272793, 0.59174776, 0.16663432,
#         0.6075627 , 0.14298646, 0.1748093 , 0.16969299, 0.35777299]),
#  'std_score_time': array([0.01816831, 0.01683006, 0.00232653, 0.01289916, 0.00933695,
#         0.00138304, 0.00200805, 0.00695966, 0.00213135, 0.01003941,
#         0.02268969, 0.00074079, 0.00047582, 0.00092719, 0.00109903,
#         0.0005508 , 0.00327722, 0.00144628, 0.01842352, 0.00171533,
#         0.03379613, 0.00170193, 0.00589674, 0.00619339, 0.00074498]),
#  'param_min_samples_split': masked_array(data=[8, 8, 11, 19, 11, 19, 11, 16, 8, 11, 16, 16, 11, 11,
#                     10, 8, 8, 11, 16, 10, 11, 8, 16, 11, 16],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 5, 4, 2, 7, 1, 3, 3, 5, 1, 2, 3, 6, 1, 6, 4, 4, 6,
#                     1, 7, 1, 7, 7, 3, 7],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[9, 11, 22, 22, 10, 10, 9, 11, 9, 11, 8, 11, 22, 10, 22,
#                     16, 8, 8, 10, 9, 22, 10, 9, 10, 16],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, None, 1, 8, 3, 7, 7, 1, 1, 12, None, 3, 7, 3, 3,
#                     None, 12, None, None, 3, None, 1, 3, 3, 12],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_bootstrap': masked_array(data=[False, True, False, True, False, False, True, False,
#                     False, False, False, True, True, True, False, True,
#                     True, True, False, True, False, True, True, True, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'min_samples_split': 8,
#    'min_samples_leaf': 1,
#    'max_features': 9,
#    'max_depth': 3,
#    'bootstrap': False},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_features': 11,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 4,
#    'max_features': 22,
#    'max_depth': 1,
#    'bootstrap': False},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 2,
#    'max_features': 22,
#    'max_depth': 8,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 7,
#    'max_features': 10,
#    'max_depth': 3,
#    'bootstrap': False},
#   {'min_samples_split': 19,
#    'min_samples_leaf': 1,
#    'max_features': 10,
#    'max_depth': 7,
#    'bootstrap': False},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 3,
#    'max_features': 9,
#    'max_depth': 7,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 3,
#    'max_features': 11,
#    'max_depth': 1,
#    'bootstrap': False},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 5,
#    'max_features': 9,
#    'max_depth': 1,
#    'bootstrap': False},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 1,
#    'max_features': 11,
#    'max_depth': 12,
#    'bootstrap': False},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 2,
#    'max_features': 8,
#    'max_depth': None,
#    'bootstrap': False},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 3,
#    'max_features': 11,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 6,
#    'max_features': 22,
#    'max_depth': 7,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 1,
#    'max_features': 10,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 6,
#    'max_features': 22,
#    'max_depth': 3,
#    'bootstrap': False},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 16,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 4,
#    'max_features': 8,
#    'max_depth': 12,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 6,
#    'max_features': 8,
#    'max_depth': None,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 1,
#    'max_features': 10,
#    'max_depth': None,
#    'bootstrap': False},
#   {'min_samples_split': 10,
#    'min_samples_leaf': 7,
#    'max_features': 9,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 1,
#    'max_features': 22,
#    'max_depth': None,
#    'bootstrap': False},
#   {'min_samples_split': 8,
#    'min_samples_leaf': 7,
#    'max_features': 10,
#    'max_depth': 1,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 7,
#    'max_features': 9,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 11,
#    'min_samples_leaf': 3,
#    'max_features': 10,
#    'max_depth': 3,
#    'bootstrap': True},
#   {'min_samples_split': 16,
#    'min_samples_leaf': 7,
#    'max_features': 16,
#    'max_depth': 12,
#    'bootstrap': True}],
#  'split0_test_score': array([0.80057143, 0.82214286, 0.78385714, 0.82457143, 0.80114286,
#         0.82214286, 0.81485714, 0.78028571, 0.78028571, 0.82314286,
#         0.821     , 0.802     , 0.82428571, 0.80057143, 0.81542857,
#         0.82128571, 0.82      , 0.82085714, 0.81814286, 0.801     ,
#         0.81442857, 0.78028571, 0.80057143, 0.80071429, 0.82171429]),
#  'split1_test_score': array([0.80057143, 0.81757143, 0.784     , 0.81828571, 0.80128571,
#         0.819     , 0.81457143, 0.78028571, 0.78028571, 0.81914286,
#         0.81742857, 0.80285714, 0.81971429, 0.80171429, 0.81271429,
#         0.81742857, 0.819     , 0.81985714, 0.81814286, 0.80042857,
#         0.81271429, 0.78028571, 0.80042857, 0.80185714, 0.82      ]),
#  'split2_test_score': array([0.79928571, 0.81585714, 0.78314286, 0.81971429, 0.79971429,
#         0.818     , 0.81271429, 0.78028571, 0.78028571, 0.81842857,
#         0.81485714, 0.801     , 0.81971429, 0.79985714, 0.81542857,
#         0.81442857, 0.81828571, 0.81871429, 0.81642857, 0.79957143,
#         0.81157143, 0.78028571, 0.79957143, 0.79985714, 0.81842857]),
#  'mean_test_score': array([0.80014286, 0.81852381, 0.78366667, 0.82085714, 0.80071429,
#         0.81971429, 0.81404762, 0.78028571, 0.78028571, 0.8202381 ,
#         0.8177619 , 0.80195238, 0.8212381 , 0.80071429, 0.81452381,
#         0.81771429, 0.81909524, 0.81980952, 0.81757143, 0.80033333,
#         0.81290476, 0.78028571, 0.80019048, 0.80080952, 0.82004762]),
#  'std_test_score': array([0.00060609, 0.00265303, 0.00037495, 0.00269037, 0.00070951,
#         0.00176512, 0.00095   , 0.        , 0.        , 0.00207457,
#         0.00251886, 0.00075892, 0.00215499, 0.00076488, 0.00127953,
#         0.0028067 , 0.00070309, 0.00087547, 0.00080812, 0.00058709,
#         0.00117417, 0.        , 0.0004416 , 0.00081927, 0.00134181]),
#  'rank_test_score': array([21,  8, 22,  2, 17,  6, 13, 23, 23,  3,  9, 15,  1, 17, 12, 10,  7,
#          5, 11, 19, 14, 23, 20, 16,  4], dtype=int32),
#  'split0_train_score': array([0.79942857, 0.85457143, 0.78271429, 0.832     , 0.80085714,
#         0.82578571, 0.81957143, 0.78028571, 0.78028571, 0.856     ,
#         0.884     , 0.80164286, 0.82707143, 0.801     , 0.8145    ,
#         0.86978571, 0.84135714, 0.84192857, 0.91571429, 0.79942857,
#         0.968     , 0.78028571, 0.79935714, 0.80078571, 0.83928571]),
#  'split1_train_score': array([0.8       , 0.85385714, 0.785     , 0.8345    , 0.80042857,
#         0.82928571, 0.82142857, 0.78028571, 0.78028571, 0.856     ,
#         0.88078571, 0.80228571, 0.82992857, 0.8005    , 0.81557143,
#         0.8685    , 0.84364286, 0.842     , 0.91478571, 0.8       ,
#         0.96714286, 0.78028571, 0.79992857, 0.8005    , 0.8395    ]),
#  'split2_train_score': array([0.80171429, 0.85621429, 0.78371429, 0.83121429, 0.80235714,
#         0.82828571, 0.82121429, 0.78028571, 0.78028571, 0.85542857,
#         0.88271429, 0.80407143, 0.82757143, 0.80235714, 0.81471429,
#         0.87214286, 0.84185714, 0.84507143, 0.91314286, 0.802     ,
#         0.96671429, 0.78028571, 0.80214286, 0.80242857, 0.84007143]),
#  'mean_train_score': array([0.80038095, 0.85488095, 0.78380952, 0.83257143, 0.80121429,
#         0.82778571, 0.8207381 , 0.78028571, 0.78028571, 0.85580952,
#         0.8825    , 0.80266667, 0.82819048, 0.80128571, 0.81492857,
#         0.87014286, 0.84228571, 0.843     , 0.91454762, 0.80047619,
#         0.96728571, 0.78028571, 0.80047619, 0.8012381 , 0.83961905]),
#  'std_train_score': array([0.00097124, 0.00098688, 0.00093557, 0.00140092, 0.00082685,
#         0.00147196, 0.00082958, 0.        , 0.        , 0.00026937,
#         0.00132095, 0.0010274 , 0.00124585, 0.00078463, 0.00046291,
#         0.00150848, 0.00098111, 0.00146501, 0.0010632 , 0.00110246,
#         0.00053452, 0.        , 0.00120138, 0.00084984, 0.00033163])}

# %% [markdown]
# ## Grid Search x Randomized Search para Estimação dos Hiperparâmetros

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html

# %% [markdown]
# Grid Search has a combination of all algorithm parameters, creating a grid.

# %%
import numpy as np
from time import time
from scipy.stats import randint as sp_randint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.datasets import load_digits

# Gets the dataset
digits = load_digits()
X, y = digits.data, digits.target

# Building the classifier
clf = RandomForestClassifier(n_estimators = 20)

# %%
# Randomized Search

# Values of the parameters that will be tested
param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Running Randomized Search
n_iter_search = 20
random_search = RandomizedSearchCV(clf, 
                                   param_distributions = param_dist, 
                                   n_iter = n_iter_search,
                                   return_train_score=True)

start = time()
random_search.fit(X, y)
print("RandomizedSearchCV ran in %.2f seconds for %d candidates for model parameters."
      % ((time() - start), n_iter_search))

# Prints the combinations of the parameters and their respective accuracy means
random_search.cv_results_
# Out:
# RandomizedSearchCV executou em 2.51 segundos para 20 candidatos a parâmetros do modelo.
# {'mean_fit_time': array([0.03226606, 0.03018363, 0.03576922, 0.05826879, 0.03517334,
#         0.02979279, 0.0251437 , 0.03163997, 0.02345339, 0.05700334,
#         0.02769613, 0.0297219 , 0.03892167, 0.03199426, 0.03271087,
#         0.02482438, 0.02065023, 0.04467638, 0.01982141, 0.03476063]),
#  'std_fit_time': array([0.00149683, 0.00163327, 0.00141961, 0.01284446, 0.00469383,
#         0.00046   , 0.00019163, 0.00076863, 0.00064321, 0.0014836 ,
#         0.00019763, 0.00128362, 0.00027435, 0.00036117, 0.00084605,
#         0.00031218, 0.00030193, 0.00050351, 0.0004298 , 0.00018396]),
#  'mean_score_time': array([0.00354131, 0.00276637, 0.00340072, 0.00423392, 0.00338666,
#         0.00343529, 0.00259709, 0.00276828, 0.0026087 , 0.00313926,
#         0.0026269 , 0.00281437, 0.00305533, 0.00255203, 0.00259693,
#         0.00257484, 0.00300376, 0.00376336, 0.00277996, 0.00300956]),
#  'std_score_time': array([1.51585767e-04, 9.51408635e-05, 1.75850723e-04, 7.09208097e-04,
#         9.74909659e-04, 4.16790516e-04, 8.21849281e-05, 4.60256965e-05,
#         2.58875396e-04, 1.27935655e-04, 5.90550195e-05, 2.67900617e-04,
#         9.94638955e-05, 3.67520519e-05, 1.29775700e-04, 1.63687083e-05,
#         2.86801156e-04, 4.81503240e-04, 1.48728865e-04, 4.31524060e-04]),
#  'param_bootstrap': masked_array(data=[False, True, True, False, True, False, True, True,
#                     True, False, False, True, True, True, True, True,
#                     False, True, False, True],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'entropy', 'gini', 'gini',
#                     'gini', 'entropy', 'entropy', 'entropy', 'gini',
#                     'gini', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[None, 3, None, None, 3, None, 3, 3, 3, None, 3, 3,
#                     None, 3, 3, 3, 3, None, 3, 3],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[2, 5, 4, 7, 7, 2, 2, 9, 1, 10, 8, 7, 7, 9, 9, 1, 2, 9,
#                     1, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[3, 6, 5, 7, 5, 6, 1, 2, 7, 9, 9, 2, 6, 7, 6, 3, 8, 3,
#                     6, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 2,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 5,
#    'min_samples_leaf': 6},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 4,
#    'min_samples_leaf': 5},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 7,
#    'min_samples_leaf': 7},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 7,
#    'min_samples_leaf': 5},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 2,
#    'min_samples_leaf': 6},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 2,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 9,
#    'min_samples_leaf': 2},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 7},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 9},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 8,
#    'min_samples_leaf': 9},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 7,
#    'min_samples_leaf': 2},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features':
#         0.99276151, 0.86255651, 0.86614996, 0.83808013, 0.99220851,
#         0.88731452, 0.87227684, 0.98858787, 0.87533126, 0.86923432,
#         0.83943098, 0.85973156, 0.99693724, 0.81995321, 0.86120221]),
#  'std_train_score': array([0.0003935 , 0.00801812, 0.00143194, 0.00105506, 0.01037921,
#         0.00209783, 0.01092697, 0.00870008, 0.01789599, 0.00104544,
#         0.00485907, 0.00776733, 0.00221055, 0.00837109, 0.00578258,
#         0.01165952, 0.01746852, 0.00171656, 0.03333769, 0.02261473])}

# %%
# Grid Search

# Using a complete grid of all parameters
param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

# Running Grid Search
grid_search = GridSearchCV(clf, param_grid = param_grid, return_train_score = True)
start = time()
grid_search.fit(X, y)

print(("GridSearchCV ran at %.2f seconds for all candidate combinations for model parameters."
      % (time() - start))
grid_search.cv_results_
# Out:
# GridSearchCV executou em 8.87 segundos para todas as combinações de candidatos a parâmetros do modelo.
# {'mean_fit_time': array([0.0268321 , 0.02451921, 0.02426394, 0.02615468, 0.02548774,
#         0.02512439, 0.03135093, 0.03105704, 0.03083913, 0.03292267,
#         0.02737737, 0.02524376, 0.03647367, 0.03344862, 0.03104472,
#         0.0517416 , 0.04824162, 0.04341102, 0.02462808, 0.02531171,
#         0.02411946, 0.02793813, 0.02762294, 0.02735162, 0.03413828,
#         0.03360184, 0.0346667 , 0.03637369, 0.02931825, 0.02685134,
#         0.0406034 , 0.03614839, 0.03242389, 0.06104136, 0.05499665,
#         0.04817398, 0.01921701, 0.01959022, 0.0189321 , 0.0221076 ,
#         0.02269069, 0.02142596, 0.03113921, 0.02938668, 0.02921391,
#         0.03211141, 0.0239497 , 0.02177993, 0.03666615, 0.0322543 ,
#         0.02796698, 0.06074222, 0.05637495, 0.05275265, 0.01992265,
#         0.01939774, 0.01959833, 0.02299802, 0.02293682, 0.02232981,
#         0.0332485 , 0.03301231, 0.03299697, 0.03643783, 0.02768588,
#         0.02238965, 0.04519471, 0.03850102, 0.03242294, 0.07235845,
#         0.06804371, 0.05737551]),
#  'std_fit_time': array([1.22870168e-03, 3.81064398e-04, 5.56486340e-04, 1.08883769e-03,
#         2.91491867e-04, 9.37292004e-05, 6.07865217e-04, 3.62706487e-04,
#         3.70586350e-04, 6.45612459e-04, 5.71330748e-04, 1.27693689e-03,
#         6.97648677e-04, 1.43394728e-03, 1.25539316e-03, 4.00931448e-04,
#         2.30134206e-03, 7.19868831e-05, 4.51487841e-04, 6.35384962e-04,
#         3.73707735e-04, 7.90113656e-04, 1.68477346e-03, 3.58487738e-04,
#         5.69547415e-04, 8.99108175e-04, 9.38877256e-04, 1.68124863e-03,
#         1.04444278e-03, 1.00978504e-03, 3.08450437e-04, 5.71509884e-05,
#         1.34482826e-03, 5.02038314e-04, 1.62019839e-03, 1.57007629e-03,
#         1.50395201e-04, 3.64368510e-04, 4.11709792e-04, 8.00274350e-04,
, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     True, True, True, True, True, True, True, True, True,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                     'entropy', 'entropy', 'entropy'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None, None,
#                     None, None, None, None, None, 3, 3, 3, 3, 3, 3, 3, 3,
#                     3, None, None, None, None, None, None, None, None,
#                     None, 3, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None,
#                     None, None, None, None, None, None, 3, 3, 3, 3, 3, 3,
#                     3, 3, 3, None, None, None, None, None, None, None,
#                     None, None],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_features': masked_array(data=[1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10,
#                     10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3, 10,
#                     10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3, 3, 3,
#                     10, 10, 10, 1, 1, 1, 3, 3, 3, 10, 10, 10, 1, 1, 1, 3,
#                     3, 3, 10, 10, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3,
#                     10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10, 1, 3, 10,
#                     1, 3, 10, 1, 3, 10],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': True,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'gini',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': 3,
#    'max_features': 10,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 1,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 3,
#    'min_samples_leaf': 10},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 1},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 3},
#   {'bootstrap': False,
#    'criterion': 'entropy',
#    'max_depth': None,
#    'max_features': 10,
#    'min_samples_leaf': 10}],
#  'split0_test_score': array([0.7641196 , 0.74252492, 0.69435216, 0.80232558, 0.82225914,
#         0.83554817, 0.81229236, 0.82890365, 0.80730897, 0.89700997,
#         0.88538206, 0.84385382, 0.91860465, 0.91362126, 0.88372093,
#         0.90531561, 0.91196013, 0.89202658, 0.7358804 , 0.73754153,
#         0.75581395, 0.83222591, 0.84717608, 0.81229236, 0.83887043,
#         0.80232558, 0.81395349, 0.90365449, 0.89368771, 0.83887043,
#         0.90697674, 0.90863787, 0.87209302, 0.9269103 , 0.89534884,
#         0.89700997, 0.79568106, 0.80398671, 0.7923588 , 0.81395349,
#         0.80564784, 0.81893688, 0.79401993, 0.80564784, 0.81561462,
#         0.90697674, 0.90033223, 0.88039867, 0.93355482, 0.91362126,
#         0.91528239, 0.9269103 , 0.92524917, 0.90531561, 0.74086379,
#         0.72923588, 0.74418605, 0.8089701 , 0.78737542, 0.83554817,
#         0.83554817, 0.81063123, 0.77242525, 0.91694352, 0.89036545,
#         0.84883721, 0.92857143, 0.92026578, 0.89700997, 0.91528239,
#         0.92026578, 0.91694352]),
#  'split1_test_score': array([0.79298831, 0.77462437, 0.75626043, 0.79298831, 0.78464107,
#         0.79799666, 0.80801336, 0.79966611, 0.80801336, 0.91318865,
#         0.86644407, 0.8196995 , 0.90651085, 0.92320534, 0.9015025 ,
#         0.92654424, 0.94824708, 0.90317195, 0.75792988, 0.76126878,
#         0.71452421, 0.81803005, 0.78964942, 0.79799666, 0.80467446,
#         0.78297162, 0.82136895, 0.90317195, 0.88480801, 0.8130217 ,
#         0.92821369, 0.91986644, 0.88981636, 0.93656093, 0.93322204,
#         0.9081803 , 0.74123539, 0.77128548, 0.76794658, 0.77295492,
#         0.81135225, 0.8263773 , 0.81803005, 0.78797997, 0.82136895,
#         0.92487479, 0.88647746, 0.88480801, 0.92988314, 0.9148581 ,
#         0.90651085, 0.94323873, 0.94991653, 0.92654424, 0.78797997,
#         0.74290484, 0.75292154, 0.78631052, 0.81803005, 0.80300501,
#         0.81135225, 0.81469115, 0.8130217 , 0.9115192 , 0.89649416,
#         0.00911305, 0.00629506, 0.01592372, 0.00182178, 0.00174486,
#         0.01306265, 0.01311547, 0.01793811, 0.01460943, 0.01975365,
#         0.01079174, 0.0209492 , 0.01020084, 0.02117726, 0.01965269,
#         0.01592127, 0.00333156, 0.02065395, 0.00331173, 0.00319998,
#         0.00108622, 0.00394586, 0.00715915, 0.01659423, 0.01812949,
#         0.01843324, 0.01530641]),
#  'rank_test_score': array([64, 63, 71, 56, 54, 43, 49, 55, 37, 23, 31, 35, 10, 12, 28, 15,  7,
#         27, 67, 68, 72, 38, 43, 59, 47, 56, 45, 24, 30, 36, 11, 17, 32,  4,
#         17, 21, 66, 62, 61, 50, 42, 47, 53, 60, 52, 19, 29, 33,  1, 14, 22,
#          5,  5, 20, 65, 70, 69, 56, 39, 46, 39, 39, 51, 13, 26, 34,  1,  7,
#         25,  3,  7, 15], dtype=int32),
#  'split0_train_score': array([0.83096234, 0.7916318 , 0.77824268, 0.83682008, 0.86861925,
#         0.88953975, 0.84267782, 0.88200837, 0.85690377, 1.        ,
#         0.98493724, 0.93138075, 1.        , 0.99246862, 0.96317992,
#         1.        , 0.99748954, 0.97405858, 0.81004184, 0.82008368,
#         0.80251046, 0.85941423, 0.86443515, 0.87698745, 0.88870293,
#         0.86861925, 0.85188285, 1.        , 0.98661088, 0.92468619,
#         1.        , 0.99497908, 0.9665272 , 1.        , 0.99665272,
#         0.97656904, 0.8460251 , 0.83430962, 0.84518828, 0.85439331,
#         0.86527197, 0.85271967, 0.8460251 , 0.86861925, 0.87698745,
#         1.        , 0.99414226, 0.95481172, 1.        , 1.        ,
#         0.9832636 , 1.        , 1.        , 0.98661088, 0.82845188,
#         0.83012552, 0.8125523 , 0.84937238, 0.87196653, 0.86610879,
#         0.88117155, 0.86861925, 0.86276151, 1.        , 0.99748954,
#         0.95146444, 1.        , 1.        , 0.98995816, 1.        ,
#         1.        , 0.99246862]),
#  'split1_train_score': array([0.86644407, 0.85976628, 0.82971619, 0.87646077, 0.87312187,
#         0.87395659, 0.84808013, 0.85893155, 0.86978297, 1.        ,
#         0.98247078, 0.93906511, 1.        , 0.99499165, 0.96327212,
#         1.        , 0.99833055, 0.97579299, 0.84641068, 0.83305509,
#         0.79298831, 0.88146912, 0.86644407, 0.87979967, 0.8639399 ,
#         0.86310518, 0.87729549, 1.        , 0.9933222 , 0.91903172,
#         1.        , 0.9966611 , 0.96661102, 1.        , 0.99833055,
#         0.97161937, 0.84891486, 0.8263773 , 0.79883139, 0.84891486,
#         0.84390651, 0.87896494, 0.87395659, 0.85642738, 0.86894825,
#         1.        , 0.9933222 , 0.97245409, 1.        , 0.99916528,
#         0.97913189, 1.        , 1.        , 0.98664441, 0.88647746,
#         0.8196995 , 0.84974958, 0.86644407, 0.89315526, 0.86644407,
#         0.85058431, 0.86227045, 0.85225376, 1.        , 0.99749583,
#         0.95409015, 1.        , 1.        , 0.99081803, 1.        ,
#         1.        , 0.98747913]),
#  'split2_train_score': array([0.82264779, 0.8817652 , 0.79017485, 0.89592007, 0.86844296,
